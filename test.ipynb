# %%
lst = [['An', 10], ['Chất lượng', 9], ['Điểm', 8]]
lst
# Out:
# [['An', 10], ['Chất lượng', 9], ['Điểm', 8]]

# %%
import pandas as pd
df = pd.DataFrame(lst, columns=['rate_title', 'rate_point'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 df = pd.DataFrame(lst, columns=['rate_title', 'rate_point'])
#
# NameError: name 'lst' is not defined

# %%
import pandas as pd
df = pd.read_csv("dxuatphat_diemden.csv")
df
# Out:
#   Nơi xuất phát    Điểm đến  Unnamed: 2 Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0        Hà Nội   Hải Phòng     Nghệ An     Sơn La   Hà Giang  Quảng Ninh
# 1    Quảng Ninh      Hà Nội  Quảng Ninh  Ninh Bình    Đà Nẵng     Sài Gòn
# 2     Ninh Bình      Hà Nội  Quảng Ninh  Ninh Bình    Đà Nẵng     Sài Gòn
# 3       Đà Nẵng      Hà Nội  Quảng Ninh  Ninh Bình    Đà Nẵng     Sài Gòn
# 4       Sài Gòn  Bình Thuận  Ninh Thuận    Đắk Lắk    Gia Lai     Phú Yên
# 5         Sa Pa      Hà Nội  Quảng Ninh  Ninh Bình    Đà Nẵng     Sài Gòn
# 6      Vũng Tàu      Hà Nội  Quảng Ninh  Ninh Bình    Đà Nẵng     Sài Gòn
# 7        Đà Lạt      Hà Nội  Quảng Ninh  Ninh Bình    Đà Nẵng     Sài Gòn
# 8     Nha Trang      Hà Nội  Quảng Ninh  Ninh Bình    Đà Nẵng     Sài Gòn
# 9    Phan Thiết      Hà Nội  Quảng Ninh  Ninh Bình    Đà Nẵng     Sài Gòn
#
#   Unnamed: 6         Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10
# 0  Thanh Hóa               SaPa  Ninh Bình        NaN         NaN
# ...
