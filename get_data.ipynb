# %%
import pandas as pd 
import requests 
import numpy
from bs4 import BeautifulSoup

# %%
URL = 'https://vexere.com/vi-VN/ve-xe-khach-tu-sai-gon-di-nha-trang-khanh-hoa-129t23591.html?date=27-09-2025&nation=84&ts=1758796742310'

responses = requests.get(URL)

if responses.status_code == 200:
    data_site = responses.text
    print('OK')
else:
    print('ERROR')
# Out:
# OK

# %%
data = BeautifulSoup(data_site,'html.parser')
with open("data_site.html", "w", encoding="utf-8") as f:
    f.write(data.prettify())

# %%
with open('data_site.html', 'r', encoding='utf-8') as f:
    data_site = BeautifulSoup(f.read(), 'html.parser')

# %%
class_container = data_site.find_all("div",class_="container" )

# %%
lst = []
for container in class_container:

    # info bus
    bus_name = container.find('div', class_='bus-name').text.strip()
    bus_rating = container.find('div', class_='bus-rating').find('span').text.strip()
    seat_type = container.find('div', class_='seat-type').get_text(strip= True)

    # from to content
    from_to_content = container.find('div', class_="from-to-content")
    to_content = from_to_content.find('div', class_='content to')
    span = to_content.find('span', class_="text-date-arrival-time")
    date_arrival = span.get_text(strip=True) if span else None

    
    # from
    from_content = from_to_content.find('div', class_='content from')
    
    # from: time - place
    from_hour = from_content.find('div',class_='hour' ).get_text(strip=True) 

    from_place = from_content.find('div',class_='place' ).get_text(strip=True)

    # to: time - place
    
    # duration
    duration = from_to_content.find('div', class_="duration").get_text(strip=True)

    to_hour = to_content.find('div', class_='content-to-info').find('div',class_='hour' ).get_text(strip=True)
    to_place = to_content.find('div', class_='content-to-info').find('div',class_='place' ).get_text(strip=True)
    
    # price
    fare = container.find('div', class_='fare')
    if fare.get_text() != None:
        
        fare = container.find('div', class_='fareSmall')
        fare_sale = container.find('div', class_='fare-sale').text if container.find('div', class_='fare-sale') else None
        price = container.find('div', class_='small').get_text(strip=True)

    # sale_percent = container.find('div', class_='percent').get_text(strip=True)

    lst.append([bus_name, bus_rating, seat_type, from_hour, from_place, duration, to_hour, to_place, date_arrival, fare_sale, price])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 35
#      33 fare = container.find('div', class_='fareSmall')
#      34 fare_sale = container.find('div', class_='fare-sale').text if container.find('div', class_='fare-sale') else None
# ---> 35 price = container.find('div', class_='fare').get_text(strip=True)
#      37 # sale_percent = container.find('div', class_='percent').get_text(strip=True)
#      39 lst.append([bus_name, bus_rating, seat_type, from_hour, from_place, duration, to_hour, to_place, date_arrival, fare_sale, price])
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
df = pd.DataFrame(lst)
df
# Out:
#                             0            1   \
# 0                    Đà Lạt ơi   4.8 (3386)
# 1                Bình Minh Tải   4.7 (3582)
# 2                    Huỳnh Gia   4.7 (8477)
# 3             An Anh Limousine   4.8 (8221)
# 4            Nam Hải Limousine   4.7 (3421)
# 5                  Khanh Phong  4.7 (16673)
# 6   Nhật Dương - Bình Minh Bus   4.9 (5777)
# 7                       Bus365    4.7 (163)
# 8                 Trà Lan Viên   4.4 (4179)
# 9                   Phương Nam   4.7 (2418)
# 10                   Đà Lạt ơi   4.8 (3386)
# 11               Bình Minh Tải   4.7 (3582)
# 12                   Huỳnh Gia   4.7 (8477)
# 13            An Anh Limousine   4.8 (8221)
# 14                 Khanh Phong  4.7 (16673)
# 15  Nhật Dương - Bình Minh Bus   4.9 (5777)
# 16                      Bus365    4.7 (163)
# 17           Nam Hải Limousine   4.7 (3421)
# 18                      Xe Nhà   4.3 (3202)
# 19                  Phương Nam   4.7 (2418)
#
# ...
