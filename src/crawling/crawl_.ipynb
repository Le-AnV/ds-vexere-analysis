# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
URL = "https://vexere.com/vi-VN/ve-xe-khach-tu-sai-gon-di-nha-trang-khanh-hoa-129t23591.html?date=11-10-2025&v=6&nation=84"

# %%
response = requests.get(URL)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
time = soup.find('p', class_='date-input-value').get_text(strip=True)

# %%
time
# Out:
# 'T7, 11/10/2025'
