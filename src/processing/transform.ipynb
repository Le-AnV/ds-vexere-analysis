# %%
import pandas as pd 
from bs4 import BeautifulSoup

# %%
def read_file(file):
    with open(file, 'r', encoding='utf-8') as f:
        content = f.read()
    return content

# %%
df = pd.read_csv('../../data/raw/sg_nt_11102025.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 565 entries, 0 to 564
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   bus_company            565 non-null    object
#  1   bus_star               565 non-null    object
#  2   bus_type               565 non-null    object
#  3   departure_time         565 non-null    object
#  4   pick_up_point          565 non-null    object
#  5   duration_h_m           565 non-null    object
#  6   arrival_time           565 non-null    object
#  7   drop_off_point         565 non-null    object
#  8   arrival_date           373 non-null    object
#  9   price_original         565 non-null    object
#  10  price_discount         565 non-null    object
#  11  discount_percent       424 non-null    object
#  12  notification           338 non-null    object
#  13  An toàn                260 non-null    float64
# ...

# %%
bus_type = df.loc[:, 'bus_type']
bus_type = pd.DataFrame(bus_type.value_counts())
bus_type
# Out:
#                                       count
# bus_type
# Limousine 32 giường (WC)                 54
# Limousine 21 phòng đơn (WC)              47
# Limousine giường nằm đơn 21 chỗ (WC)     47
# Limousine 24 Phòng Đôi                   39
# Limousine 20 giường phòng (WC)           34
# ...                                     ...
# Limousine 34 Giường (rèm - không WC)      1
# Giường nằm 41 chỗ                         1
# Limousine 36 Giường (Mới)                 1
# Limousine 34 Phòng                        1
# Limousine 30 Phòng Đơn (WC)               1
#
# [66 rows x 1 columns]

# %%
val = input()
df[df['bus_type'] == val]
# Out:
#     bus_company    bus_star                              bus_type  \
# 205     Hà Linh  4.1 (1329)  Limousine 34 Giường (rèm - không WC)
#
#     departure_time             pick_up_point duration_h_m arrival_time  \
# 205          22:45  • An Sương - Siêu thị đá           6h        04:45
#
#             drop_off_point arrival_date price_original  ... discount_percent  \
# 205  • Văn Phòng Nha Trang      (12/10)        450.000  ...             -29%
#
#     notification An toàn  Thông tin chính xác  Thông tin đầy đủ  \
# 205          NaN     4.4                  4.3               4.3
#
#      Thái độ nhân viên  Tiện nghi & thoải mái  Chất lượng dịch vụ  Đúng giờ  \
# 205                4.2                    4.0                 4.0       4.8
#
#      Unnamed: 20
# 205          NaN
#
# [1 rows x 21 columns]

# %%
bus_rating = df['bus_star']
bus_rating = bus_rating.str.split(' ', expand=True)

# %%
amount_rating = bus_rating.iloc[:, 1]
amount_rating = amount_rating.str.strip('()')
amount_rating
# Out:
# 0       3425
# 1       3650
# 2       8534
# 3       8322
# 4      16845
#        ...
# 560     3425
# 561     3425
# 562     3425
# 563      279
# 564      279
# Name: 1, Length: 565, dtype: object

# %%
bus_rating.iloc[:, 0].value_counts()
# Out:
# 0
# 4.7    144
# 4      112
# 3.8     88
# 3.1     39
# 4.3     23
# 4.6     23
# 4.9     20
# 4.5     19
# 2.8     17
# 3.6     16
# 4.8     15
# 5       12
# 4.2     10
# 4.1      9
# 4.4      7
# 3.7      3
# 3.5      3
# 3.9      3
# 3.3      1
# 0        1
# Name: count, dtype: int64
